# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminmulla/CaseStudy/blob/Netflix/Netflix_CaseStudy_Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Project : Netflix Business Case Study **:
#
#
# ---
#
#
# >Steps :
#
# 1. Data Reading
# 2. Data Cleaning
#     a. Finding unwanted coloumns
#     b. Identifying Null values and missing data and fixing it.
# 5. Basic Ananlysis
# 6. Details Ananlysis
# 7. Plotting graphs
# 8. Business Insights
# 9. Recommendations

# %% [markdown]
# ## **STEP 1: Data Reading >>>>**
#
# ---

# %%
##
# Importing all required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
##
netflix_df = pd.read_csv("original_netflix.csv")

# %%
##
original_df1 = pd.read_csv("original_netflix.csv")

# %%
original_df1.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix_df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix_df.shape
# Out:
# (8807, 12)

# %% [markdown]
#  *File uploaded and read succussfuly. CSV has systematic data with proper column format. No need to used /t or any other parameter to read the file. and hence step 1 is completed succussfuly. *

# %% [markdown]
# ## **STEP 2: Cleaning of Data>>>>**
#
# ---

# %%
netflix_df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
#  *All coloumns are neccessary for business analysis. 'show_id' is also helps us to find duplicate records , if there is no duplicate records then we can drop 'show id'*

# %%
netflix_df['show_id'].value_counts()
# Out:
# s1       1
# s5875    1
# s5869    1
# s5870    1
# s5871    1
#         ..
# s2931    1
# s2930    1
# s2929    1
# s2928    1
# s8807    1
# Name: show_id, Length: 8807, dtype: int64

# %% [markdown]
# *no of rows and unique values of show_id is exactly same. That means we doesnt have duplicate show_id , so that we can drop it from our analysis data.*

# %%
##
netflix_df.drop(['show_id'], inplace= True, axis=1)

# %%
netflix_df.head(5)
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# Here we are finding null values with percentile so that we can took some decision on null data.
for i in netflix_df.columns:
    null_rate = netflix_df[i].isna().sum() / len(netflix_df) * 100
    if null_rate > 0 :
        print("{} null rate: {}%".format(i,round(null_rate,2)))
# Out:
# director null rate: 29.91%
# cast null rate: 9.37%
# country null rate: 9.44%
# date_added null rate: 0.11%
# rating null rate: 0.05%
# duration null rate: 0.03%

# %%
netflix_df[netflix_df['director'].str.len() < 1]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
netflix_df.shape
# Out:
# (8807, 11)

# %%
##
# We can remove all rows which contains null values in Director , cast , country , date_added , rating , duration

indexList_tobeRemoved = netflix_df[ netflix_df['director'].isna() & netflix_df['cast'].isna() & netflix_df['country'].isna() ].index

#df.head(15) // 2634, 352,96
indexList_tobeRemoved.shape
# Out:
# (96,)

# %%
##
# Dropping all 96 records which having null values in rows
netflix_df.drop(indexList_tobeRemoved , inplace=True)

# %%
netflix_df.shape
# Out:
# (8711, 11)

# %%
# Here we are finding null values with percentile so that we can took some decision on null data.
for i in netflix_df.columns:
    null_rate = netflix_df[i].isna().sum() / len(netflix_df) * 100
    if null_rate > 0 :
        print("{} null rate: {}%".format(i,round(null_rate,2)))
# Out:
# director null rate: 29.14%
# cast null rate: 8.37%
# country null rate: 8.44%
# date_added null rate: 0.11%
# rating null rate: 0.05%
# duration null rate: 0.03%

# %%
#director has more than 25% null data, we should replace it with 'NO Director'

# %%
##
netflix_df.director.fillna('NO Director', inplace= True)

# %%
##
#country has more than 8% null data, we should replace it with 'Not Specified'

# %%
##
netflix_df.country.fillna('Not Specified', inplace= True)

# %%
#Cast has more than 8% null data, we should replace it with 'Not Specified'

# %%
##
netflix_df.cast.fillna('Not Specified', inplace= True)

# %%
netflix_df
# Out:
#          type                 title         director  \
# 0       Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show         Blood & Water      NO Director
# 2     TV Show             Ganglands  Julien Leclercq
# 4     TV Show          Kota Factory      NO Director
# 5     TV Show         Midnight Mass    Mike Flanagan
# ...       ...                   ...              ...
# 8801    Movie               Zinzana  Majid Al Ansari
# 8802    Movie                Zodiac    David Fincher
# 8804    Movie            Zombieland  Ruben Fleischer
# 8805    Movie                  Zoom     Peter Hewitt
# 8806    Movie                Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                         Not Specified
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...

# %% [markdown]
# ## **STEP 3: Basic Ananlysis >>>>**
#
# ---

# %%
netflix_df.shape
# Out:
# (8711, 11)

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8711 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8711 non-null   object
#  1   title         8711 non-null   object
#  2   director      8711 non-null   object
#  3   cast          8711 non-null   object
#  4   country       8711 non-null   object
#  5   date_added    8701 non-null   object
#  6   release_year  8711 non-null   int64
#  7   rating        8707 non-null   object
#  8   duration      8708 non-null   object
#  9   listed_in     8711 non-null   object
#  10  description   8711 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 816.7+ KB

# %%
netflix_df.head(5)
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water      NO Director
# 2  TV Show             Ganglands  Julien Leclercq
# 4  TV Show          Kota Factory      NO Director
# 5  TV Show         Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 0                                      Not Specified  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Not Specified
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  Not Specified
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# find the unique rating and total count of movies and shows to understand rating coloumn
rating_ds = netflix_df['rating'].value_counts()

# %%
rating_ds = pd.DataFrame(rating_ds)

# %%
rating_ds
# Out:
#           rating
# TV-MA       3174
# TV-14       2139
# TV-PG        845
# R            799
# PG-13        490
# TV-Y7        327
# TV-Y         293
# PG           286
# TV-G         218
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1

# %%
plt.figure(figsize=(15,10))

sns.barplot(data=rating_ds, x=rating_ds.index, y='rating' )
plt.title('Fig 1>> Distribution of Shows by Rating  ')
plt.xlabel('Audience Category')
plt.ylabel('Count of Shows')

# Add labels to the bars
for i, v in enumerate(rating_ds.values):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
##
# Dividing rating into three category for better undestanding Adults, Kids, Teens
rating = {
    'TV-Y': 'Kids',
    'TV-Y7': 'Kids',
    'TV-G': 'Kids',
    'PG': 'Kids',
    'TV-PG': 'Kids',
    'PG-13': 'Teens',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-MA': 'Adults',
    'NC-17': 'Adults',
    'NR': 'Adults',
    'UR': 'Adults',
    'TV-Y7-FV': 'Kids',
    'G': 'Kids'
}

Audience_Type_df = pd.DataFrame(rating.items(), columns=['rating', 'Audience_Category'])

# %%
##
#Doing simple merge to to assign category to each show
df =  netflix_df.merge(Audience_Type_df)

# %%
df.head(3)
# Out:
#     type                 title         director  \
# 0  Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  Movie          The Starling   Theodore Melfi
# 2  Movie             Grown Ups     Dennis Dugan
#
#                                                 cast        country  \
# 0                                      Not Specified  United States
# 1  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 2  Adam Sandler, Kevin James, Chris Rock, David S...  United States
#
#            date_added  release_year rating duration         listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min     Documentaries
# 1  September 24, 2021          2021  PG-13  104 min  Comedies, Dramas
# 2  September 20, 2021          2010  PG-13  103 min          Comedies
#
#                                          description Audience_Category
# 0  As her father nears the end of his life, filmm...             Teens
# ...

# %%
##
# Total counts of shows using Audience_Category
Audience_Type_df = df['Audience_Category'].value_counts()

# %%
Audience_Type_df
# Out:
# Adults    4059
# Teens     2629
# Kids      2016
# Name: Audience_Category, dtype: int64

# %%
##
Audience_Type_df = pd.DataFrame(Audience_Type_df)

# %%
Audience_Type_df
# Out:
#         Audience_Category
# Adults               4059
# Teens                2629
# Kids                 2016

# %%
Audience_Type_df.values
# Out:
# array([[4059],
#        [2629],
#        [2016]])

# %%
# Plot a bar graph with different colors for each bar
sns.barplot(data=Audience_Type_df, x=Audience_Type_df.index, y='Audience_Category' )
plt.title('Fig 2>> Distribution of Audience Category ')
plt.xlabel('Audience Category')
plt.ylabel('Count of Shows')

# Add labels to the bars
for i, v in enumerate(Audience_Type_df.values):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %%
## Top 5 Actors ( TV shows and Movies)
df_Split_Cast = netflix_df[netflix_df.cast != 'Not Specified'].set_index('title').cast.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
#df_Split_Cast = netflix_df[netflix_df['cast'!='Not Specified']].cast.str.split(',', expand=True).stack()
Cast_df = df_Split_Cast.value_counts().rename('Cast wise Count')

Top10_Cast_df = pd.DataFrame(Cast_df)
Top10_Cast_df.head(5)
# Out:
#                   Cast wise Count
# Anupam Kher                    43
# Shah Rukh Khan                 35
# Julie Tejwani                  33
# Naseeruddin Shah               32
# Takahiro Sakurai               32

# %%
# Top 5 Movie Actors
df_filtered = netflix_df[(netflix_df['type'] == 'Movie') ]
df_split_cast = df_filtered['cast'].str.split(', ', expand=True).stack().value_counts().rename('Cast wise Count')
df_split_cast[df_split_cast.index != 'Not Specified'].head(5)
# Out:
# Anupam Kher         42
# Shah Rukh Khan      35
# Naseeruddin Shah    32
# Om Puri             30
# Akshay Kumar        30
# Name: Cast wise Count, dtype: int64

# %%
# Top 5 TV Show Actors
df_filtered = netflix_df[(netflix_df['type'] == 'TV Show') ]
df_split_cast = df_filtered['cast'].str.split(', ', expand=True).stack().value_counts().rename('Cast wise Count')
df_split_cast[df_split_cast.index != 'Not Specified'].head(5)
# Out:
# Takahiro Sakurai    25
# Yuki Kaji           19
# Junichi Suwabe      17
# Daisuke Ono         17
# Ai Kayano           17
# Name: Cast wise Count, dtype: int64

# %% [markdown]
# Anupam Kher and Shah Rukh Khan seems very popular in Netflix

# %%
## TOP 5 Directors ( TV shows and Movies)
df_Split_director = netflix_df[netflix_df.director != 'NO Director'].set_index('title').director.str.split(',', expand=True).stack().reset_index(level=1, drop=True)
df_Split_director = df_Split_director.value_counts().rename('Count')
#df_Split_director = df_Split_director['director'].value_counts()
Top10_Directors = pd.DataFrame(df_Split_director)
Top10_Directors.head(5)
# Out:
#                Count
# Rajiv Chilaka     22
# Raúl Campos       18
#  Jan Suter        18
# Marcus Raboy      16
# Suhas Kadav       16

# %% [markdown]
# Rajiv Chilaka has more than 20+ shows and movies in Netflix

# %%
# Top 5 Movie Directors
df_filtered = netflix_df[(netflix_df['type'] == 'Movie') ]
df_split_cast = df_filtered['director'].str.split(', ', expand=True).stack().value_counts().rename('director wise Count')
df_split_cast[df_split_cast.index != 'NO Director'].head(5)
# Out:
# Rajiv Chilaka    22
# Jan Suter        21
# Raúl Campos      19
# Suhas Kadav      16
# Jay Karas        15
# Name: director wise Count, dtype: int64

# %%
# Top 5 TV Show Directors
df_filtered = netflix_df[(netflix_df['type'] == 'TV Show') ]
df_split_cast = df_filtered['director'].str.split(', ', expand=True).stack().value_counts().rename('director wise Count')
df_split_cast[df_split_cast.index != 'NO Director'].head(5)
# Out:
# Alastair Fothergill      3
# Ken Burns                3
# Iginio Straffi           2
# Gautham Vasudev Menon    2
# Hsu Fu-chun              2
# Name: director wise Count, dtype: int64

# %%
# Top 5 TV Show Director
df_filtered = netflix_df[(netflix_df['type'] == 'TV Show') ]
df_split_cast = df_filtered['director'].str.split(', ', expand=True).stack().value_counts().rename('director wise Count')
df_split_cast[df_split_cast.index != 'NO Director'].head(5)
# Out:
# Alastair Fothergill      3
# Ken Burns                3
# Iginio Straffi           2
# Gautham Vasudev Menon    2
# Hsu Fu-chun              2
# Name: director wise Count, dtype: int64

# %% [markdown]
# ## 4 >> Details Ananlysis & 5>> Plotting graphs
#
# ---

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8711 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8711 non-null   object
#  1   title         8711 non-null   object
#  2   director      8711 non-null   object
#  3   cast          8711 non-null   object
#  4   country       8711 non-null   object
#  5   date_added    8701 non-null   object
#  6   release_year  8711 non-null   int64
#  7   rating        8707 non-null   object
#  8   duration      8708 non-null   object
#  9   listed_in     8711 non-null   object
#  10  description   8711 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 816.7+ KB

# %%
##
#to get years wise movies and TV show count we need to convert date_added into date
netflix_df["date_added"] = pd.to_datetime(netflix_df['date_added'])
netflix_df['year_added'] =  netflix_df[ ("date_added")].dt.year
df_year = netflix_df['year_added'].value_counts()

# %%
##
df_year_movie= pd.DataFrame(netflix_df[netflix_df['type'] == 'Movie']['year_added'].value_counts())

df_year_movie.columns = ['Movie_Count']
df_year_movie
# Out:
#         Movie_Count
# 2019.0         1418
# 2020.0         1281
# 2018.0         1237
# 2021.0          986
# 2017.0          838
# 2016.0          253
# 2015.0           56
# 2014.0           19
# 2011.0           13
# 2013.0            6
# 2012.0            3
# 2009.0            2
# 2008.0            1
# 2010.0            1

# %%
##
df_year_show= pd.DataFrame(netflix_df[netflix_df['type'] == 'TV Show']['year_added'].value_counts())

df_year_show.columns = ['TV_Shows_Count']

df_year_show
# Out:
#         TV_Shows_Count
# 2020.0             579
# 2019.0             577
# 2021.0             470
# 2018.0             402
# 2017.0             348
# 2016.0             174
# 2015.0              26
# 2014.0               5
# 2013.0               5
# 2008.0               1

# %%
##
year_M_S_df = df_year_show.merge(df_year_movie, left_index=True, right_index=True)

year_M_S_df = year_M_S_df.sort_index()

# %%
year_M_S_df
# Out:
#         TV_Shows_Count  Movie_Count
# 2008.0               1            1
# 2013.0               5            6
# 2014.0               5           19
# 2015.0              26           56
# 2016.0             174          253
# 2017.0             348          838
# 2018.0             402         1237
# 2019.0             577         1418
# 2020.0             579         1281
# 2021.0             470          986

# %%
years = year_M_S_df.index
tv_show_counts = year_M_S_df['TV_Shows_Count']
movie_counts = year_M_S_df['Movie_Count']
# Plotting the line graph

plt.plot(years, tv_show_counts, marker='o', label='TV Shows')
plt.plot(years, movie_counts, marker='o', label='Movies')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Fig 3>> Counts of TV Shows and Movies Over the Years')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# From 2014 OTT trend is upward direction till 2019-20 after that seems little down tread.

# %%
##
releaseYear_ds= netflix_df[netflix_df['type'] == 'Movie']['release_year'].value_counts().sort_index(ascending = False)
releaseYear_ds = releaseYear_ds.head(14)

# %%
##
AddedYear_ds= netflix_df[netflix_df['type'] == 'Movie']['year_added'].value_counts().sort_index(ascending = False)
AddedYear_ds = AddedYear_ds.head(14)

# %%
AddedYear_ds
# Out:
# 2021.0     986
# 2020.0    1281
# 2019.0    1418
# 2018.0    1237
# 2017.0     838
# 2016.0     253
# 2015.0      56
# 2014.0      19
# 2013.0       6
# 2012.0       3
# 2011.0      13
# 2010.0       1
# 2009.0       2
# 2008.0       1
# Name: year_added, dtype: int64

# %%
releaseYear_ds
# Out:
# 2021    271
# 2020    516
# 2019    626
# 2018    767
# 2017    766
# 2016    658
# 2015    398
# 2014    264
# 2013    224
# 2012    173
# 2011    145
# 2010    153
# 2009    118
# 2008    113
# Name: release_year, dtype: int64

# %%
#plt.figure(figsize=(15,10))

years = AddedYear_ds.index
released_counts = releaseYear_ds.values
Added_counts = AddedYear_ds.values
# Plotting the line graph

plt.plot(years, released_counts, marker='o', label='Count of Released Movies')
plt.plot(years, Added_counts, marker='o', label='Count of Added Movies')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Fig 4>> Comparision Between Added Years and Release Years( Movies) ')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a pair plot
pp = sns.pairplot(netflix_df)
pp.fig.suptitle('Fig 5>> Pairplot: Added Years and Release Years ')

# Display the plot
plt.show()

# %%
##
tvShow_Movie_df = netflix_df['type'].value_counts()
tvShow_Movie_df = pd.DataFrame(tvShow_Movie_df)
tvShow_Movie_df
# Out:
#          type
# Movie    6114
# TV Show  2597

# %%
tvShow_Movie_df.index
# Out:
# Index(['Movie', 'TV Show'], dtype='object')

# %%
tvShow_Movie_df.values
# Out:
# array([[6114],
#        [2597]])

# %%
type(tvShow_Movie_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#sns.barplot( x= tvShow_Movie_df.index, y = tvShow_Movie_df.values)
# Adding labels and title


sns.axes_style('white')
sns.set_style('white')
sns.barplot(x = tvShow_Movie_df.index, y = 'type', data=tvShow_Movie_df)
plt.xlabel('Shows Type',fontsize=10)
plt.ylabel('Count of Shows ', fontsize=10)
plt.title('Fig 6.1>> Comparing the Number of Movies and Shows: A Comprehensive Analysis  ', fontsize=15)
plt.show()

# %%
count_df = netflix_df.groupby(['country', 'type']).size().reset_index(name='Count')
count_df = count_df.sort_values('Count', ascending = False)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=count_df.head(20), x='country', y='Count', hue='type')
plt.xlabel('Country')
plt.xticks(rotation=90,fontsize=12)
plt.ylabel('Count')
plt.title('Fig 6.2>>Count of TV Shows and Movies by Country')

# Show the plot
plt.show()

# %%
content_df = netflix_df.groupby(['country', 'listed_in']).size().reset_index(name='Count')
content_df = content_df.sort_values('Count', ascending = False)

# %%
content_df.head(20)
# Out:
#             country                                          listed_in  Count
# 2296  United States                                      Documentaries    249
# 2409  United States                                    Stand-Up Comedy    209
# 810           India             Comedies, Dramas, International Movies    120
# 832           India                       Dramas, International Movies    118
# 831           India   Dramas, Independent Movies, International Movies    108
# 2191  United States                 Children & Family Movies, Comedies     90
# 2324  United States                                             Dramas     88
# 2238  United States                                           Comedies     84
# 2187  United States                           Children & Family Movies     80
# 2372  United States                                           Kids' TV     77
# 1050          Japan               Anime Series, International TV Shows     75
# ...

# %%
##
netflix_df['month_added'] =  netflix_df[ ("date_added")].dt.month_name()
Month_df = netflix_df['month_added'].value_counts()

# %%
type(Month_df)
# Out:
# pandas.core.series.Series

# %%
##
Month_df = pd.DataFrame(Month_df)

# %%
##
Month_df.rename(columns={'month_added': 'Monthly_Count'}, inplace=True)

# %%
##
# Define the custom sorting order
custom_order = [
    'January', 'February', 'March', 'April', 'May', 'June', 'July',
    'August', 'September', 'October', 'November', 'December']
# Apply the custom sorting order to the Month column
Month_df = Month_df.reindex(custom_order)

# Sort the DataFrame by the Month column
#Month_df.sort_values(Month_df.index, inplace=True)

Month_df
# Out:
#            Monthly_Count
# January              735
# February             560
# March                736
# April                755
# May                  620
# June                 718
# July                 813
# August               746
# September            755
# October              750
# November             703
# December             810

# %%
Month_df
# Out:
#            Monthly_Count
# January              735
# February             560
# March                736
# April                755
# May                  620
# June                 718
# July                 813
# August               746
# September            755
# October              750
# November             703
# December             810

# %%
# Plotting the pie chart
plt.pie(Month_df.Monthly_Count, labels=Month_df.index, autopct='%1.1f%%', startangle=90)

# Aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Chart title
plt.title('Fig 7>> Percentage Distribution of Release Counts Across Months')

# Display the chart
plt.show()

# %% [markdown]
# on Basis on release date , July and December are good time period to release
#  OTT content.

# %%
netflix_df.head(3)
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water      NO Director
# 2  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                      Not Specified  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Not Specified
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  year_added month_added
# ...

# %%
netflix_df.listed_in.nunique()
# Out:
# 512

# %%
##
df_split = netflix_df.listed_in.str.split(',', expand=True).stack()
listed_in_df = df_split.value_counts().rename('list wise Count')

listed_in_df = pd.DataFrame(listed_in_df)
#listed_in_df = listed_in_df.reset_index(drop=True)
listed_in_df = listed_in_df.head(11)

# %%
##
is_duplicate = listed_in_df.index.duplicated()
listed_in_df=listed_in_df[~is_duplicate]
listed_in_df
# Out:
#                           list wise Count
#  International Movies                2618
# Dramas                               1596
# Comedies                             1210
# Action & Adventure                    859
#  Dramas                               827
# Documentaries                         824
# International TV Shows                761
#  Independent Movies                   736
#  TV Dramas                            695
#  Romantic Movies                      611
# Children & Family Movies              598

# %%
##
# Reset the index to a column
listed_in_df = listed_in_df.reset_index()

# Drop duplicate indices
df_no_duplicates = listed_in_df.drop_duplicates(subset='index').set_index('index')

# %%
listed_in_df  = df_no_duplicates

# %%
listed_in_df
# Out:
#                           list wise Count
# index
#  International Movies                2618
# Dramas                               1596
# Comedies                             1210
# Action & Adventure                    859
#  Dramas                               827
# Documentaries                         824
# International TV Shows                761
#  Independent Movies                   736
#  TV Dramas                            695
#  Romantic Movies                      611
# Children & Family Movies              598

# %%
plt.figure(figsize=(15,10))
sns.axes_style('white')
sns.set_style('white')
sns.barplot(x = listed_in_df.index, y = 'list wise Count', data=listed_in_df)
plt.xlabel('Gener of Shows',fontsize=10)
plt.xticks(rotation=90,fontsize=12)
plt.ylabel('Count of Shows ', fontsize=10)
plt.title('Fig 8>>Comparing the Number of Movies and Shows by Content: A Comprehensive Analysis  ', fontsize=15)
plt.show()

# %%
##
GenerWise_DF= netflix_df[netflix_df['listed_in'].isin(['International Movies','Dramas','Comedies'])]
GenerWise_DF
# Out:
#        type                          title             director  \
# 27    Movie                      Grown Ups         Dennis Dugan
# 112   Movie                          Worth       Sara Colangelo
# 129   Movie             An Unfinished Life      Lasse Hallström
# 142   Movie                Freedom Writers  Richard LaGravenese
# 152   Movie  Janoskians: Untold and Untrue         Brett Weiner
# ...     ...                            ...                  ...
# 8675  Movie                         Victor    Brandon Dickerson
# 8685  Movie                            VS.             Ed Lilly
# 8691  Movie                      Wakefield        Robin Swicord
# 8696  Movie                      War Horse     Steven Spielberg
# 8730  Movie              Where's the Money      Scott Zabielski
#
#                                                    cast  \
# 27    Adam Sandler, Kevin James, Chris Rock, David S...
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# ...

# %%
df_Split_director = GenerWise_DF[GenerWise_DF.director != 'NO Director'].set_index('title').director.str.split(',', expand=True).stack().reset_index(level=1, drop=True)
df_Split_director = df_Split_director.value_counts().rename('Count')
#df_Split_director = df_Split_director['director'].value_counts()
Top10_Directors = pd.DataFrame(df_Split_director)
Top10_Directors.head(11)
# Out:
#                   Count
# Steven Spielberg      3
# Dennis Dugan          2
# Jon Lucas             2
# Aaron Sorkin          2
# George Clooney        2
# Martin Scorsese       2
# Jay Roach             2
#  Scott Moore          2
# John Lee Hancock      2
# Robert Luketic        1
# Andrew Niccol         1

# %%
df_Split_director = GenerWise_DF[GenerWise_DF.cast != 'NO Director'].set_index('title').cast.str.split(',', expand=True).stack().reset_index(level=1, drop=True)
df_Split_director = df_Split_director.value_counts().rename('Count')
#df_Split_director = df_Split_director['director'].value_counts()
Top10_Directors = pd.DataFrame(df_Split_director)
Top10_Directors.head(11)
# Out:
#                        Count
# Adam Sandler               7
#  Mike Epps                 6
# David Spade                5
#  London Hughes             4
#  Kate Winslet              4
#  John Michael Higgins      4
#  David Oyelowo             4
#  Rob Riggle                4
#  James Marsden             4
#  Kathryn Hahn              4
#  Fred Armisen              4

# %%
#netflix_df[['type','country','listed_in']]

df_split = netflix_df.listed_in.str.split(',', expand=True).stack()
listed_in_df = df_split.value_counts().rename('list wise Count')

listed_in_df = pd.DataFrame(listed_in_df)
#listed_in_df = listed_in_df.reset_index(drop=True)
listed_in_df = listed_in_df.head(11)

# %%
generWise_country_df = netflix_df[['country','listed_in']].value_counts().sort_values(ascending = False).rename('Count')

# %%
generWise_country_df = pd.DataFrame(generWise_country_df)
generWise_country_df.head(5)
# Out:
#                                                                 Count
# country       listed_in
# United States Documentaries                                       249
#               Stand-Up Comedy                                     209
# India         Comedies, Dramas, International Movies              120
#               Dramas, International Movies                        118
#               Dramas, Independent Movies, International Movies    108

# %%
# Create a heatmap
sns.heatmap(generWise_country_df.head(10))
plt.title('Fig 9>>Country and Conetent Heatmap ', fontsize=15)
# Display the plot
plt.show()

# %%
typeWise_country_df = netflix_df[['country','type']].value_counts().sort_values(ascending = False).rename('Count')
typeWise_country_df= pd.DataFrame(typeWise_country_df)

# %%
netflix_df.head(10)
# Out:
#        type                             title                       director  \
# 0     Movie              Dick Johnson Is Dead                Kirsten Johnson
# 1   TV Show                     Blood & Water                    NO Director
# 2   TV Show                         Ganglands                Julien Leclercq
# 4   TV Show                      Kota Factory                    NO Director
# 5   TV Show                     Midnight Mass                  Mike Flanagan
# 6     Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7     Movie                           Sankofa                   Haile Gerima
# 8   TV Show     The Great British Baking Show                Andy Devonshire
# 9     Movie                      The Starling                 Theodore Melfi
# 11  TV Show                  Bangkok Breaking              Kongkiat Komesiri
#
#                                                  cast  \
# 0                                       Not Specified
# ...

# %%
netflix_df.duration.fillna('Not Specified', inplace= True)

# %%
data = netflix_df['duration'].loc[netflix_df['type'] =='TV Show'].tolist()

# %%
# Example data


# Create a histogram
##plt.hist(data, bins=100 )

# Create a histogram with percentages
plt.hist(data, bins=50)

# Set labels and title
plt.xlabel('Duration')
plt.xticks(rotation=90,fontsize=12)
plt.ylabel('Frequency')
plt.title('Fig 10>> Duration-wise Histogram')

# Display the plot
plt.show()

# %% [markdown]
# There are lots of shows for season 1

# %% [markdown]
# ### ***6>>Business Insights***
#
# ---
#
#
# 1.	There are approx. 70% movies than tv shows.
# 2.	United state has dominant market for Netflix, followed by India , United kingdom and Japan
# 3.	From 2014 OTT has uptrend till 2019-20, And after that seems little down tread.
# 4.	TV-MA and TV-14 rating has extremely high content than other rating
# 5.	From last decade movies released on Netflix are incredibly greater and its almost more than 6900%
# 6.	Cananda, Spain , Egypt, Nigeria, Indonesia, Turkey, France, Philippines, Mexico has very less amount of content in both type TV Shows and Movie. As compare to USA, India, UK and Japan
# 7.	Major TV shows and Movies are listed on International Movies, Dramas, Comedies and Action Adventure. If look as individual country then USA has more hold on Documentaries and Stand-up Comedy
# 8.	July and December are months when more Movies and TV Shows are released ,that is more than 9% . But in wide picture all months have nice amount of released and added content, only Feb and May months has very less released that is less than 7%
# 9.	Most TV Shows and Movies are released with season 1 only.

# %% [markdown]
# ### ***7>> Reccomendations***
#
# ---
#
# 1. USA is Dominant , Netflix will have to run marketing campaign in other countries. And try to convince local directors and actors to upload there shows on Netflix, Like Cananda, Spain , Egypt, Nigeria, Indonesia, Turkey, France, Philippines, Mexico
# 2. Netflix must add more content in reginal language so that Netflix can increase its popularity in more countries widely , like Turkey, France and Egypt etc
# 3. Netflix is showing little down trend from 2021. might be because of 2020 is pandemic year  after that it goes little down. Still have to promote more add and offer more discounts to people so that there interest will not disappears.
# 4. Comparatively teenage and kids content are also less. Netflix encourage directors and actors to release more content for these rating.
# 4. There is no data provided to check popularity of shows other wise would recommend that Netflix should convince most popular shows with session 1 to release next sessions
